# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("result_data.csv")
df = pd.DataFrame(data)
df.head()
# Out:
#                                     title                company      salary  \
# 0         Senior Python Engineer (Django)               Adwisely  $3000–4000
# 1                 Senior Python Developer              Starkflow         NaN
# 2  Senior Python Engineer (Data Platform)  SoftConstruct Ukraine         NaN
# 3  Senior / Lead Python Software Engineer                   EPAM         NaN
# 4                Python backend developer            Receptor.AI         NaN
#
#                                             location  \
# 0                                          віддалено
# 1                                          віддалено
# 2                                          віддалено
# 3  Київ, Харків, Львів, Дніпро, Одеса, Вінниця, І...
# 4                                          віддалено
#
#                                          description  \
# 0  Adwisely (formerly RetargetApp) is a marketing...
# 1  On behalf of our client — crypto-assets tradin...
# ...

# %%
tech_series = df["technologies"].str.split(", ", expand=True).stack()
tech_counts = tech_series.value_counts()
top_tech_counts = tech_counts.head(20)

plt.figure(figsize=(10, 6))
top_tech_counts.plot(kind="bar", color="skyblue")
plt.title("Most Common Technologies")
plt.xlabel("Technologies")
plt.ylabel("Count")
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()

# %%
city_counts = df["location"].value_counts()
top_5_cities = city_counts.head(5)

plt.figure(figsize=(8, 8))
plt.pie(top_5_cities, labels=top_5_cities.index, autopct="%1.1f%%")
plt.title("Top 5 locations by Number of Vacancies")
plt.show()

# %%
company_counts = df.groupby("location")["company"].nunique()

top_5_cities = company_counts.nlargest(5)

plt.figure(figsize=(10, 6))
top_5_cities.plot(kind="bar", color="skyblue")

plt.title("Top 5 Locations with the Most Companies")
plt.xlabel("Location")
plt.ylabel("Number of Companies")
plt.xticks(rotation=45, ha="right")
plt.tight_layout()

plt.show()
